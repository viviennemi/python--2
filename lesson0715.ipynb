# %%
(404,"error")
# Out:
# (404, 'error')

# %%
def get_tuple():
    return (404,"error")

# %%
#tuple拆解法

(code, message) = get_tuple()
print(code)
print(message)
# Out:
# 404
# error

# %%
#1個元素的tuple
(404,)
# Out:
# (404,)

# %%
list()
# Out:
# []

# %%
list(range(1,10))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
list(('a','b','c',1,2,3))
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
#浮號建立
stu1=[78,98,56,74,79]
stu1
# Out:
# [78, 98, 56, 74, 79]

# %%
for score in stu1:
    print(score)
# Out:
# 78
# 98
# 56
# 74
# 79
