# %%
import csv
filename = 'aqx_p_432.csv'
with open(filename,encoding='utf-8',newline='') as file:
    data = csv.DictReader(file)
    #for item in data:
        #print(item)
    #標題與對應值
    data_list = list(data)

data_list
# Out:
# [{'sitename': '基隆',
#   'county': '基隆市',
#   'aqi': '18',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '4.1',
#   'co': '0.19',
#   'o3': '22.7',
#   'o3_8hr': '15.3',
#   'pm10': '',
#   'pm2.5': '7',
#   'no2': '11.1',
#   'nox': '20.1',
#   'no': '8.9',
#   'wind_speed': '1.5',
#   'wind_direc': '110',
#   'publishtime': '2023/07/22 11:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '4.7',
#   'pm10_avg': '',
#   'so2_avg': '0',
#   'longitude': '121.760056',
#   'latitude': '25.129167',
#   'siteid': '1'},
#  {'sitename': '汐止',
#   'county': '新北市',
#   'aqi': '18',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.2',
#   'co': '0.27',
#   'o3': '29.2',
#   'o3_8hr': '12.3',
#   'pm10': '17',
#   'pm2.5': '5',
#   'no2': '11.7',
#   'nox': '16',
#   'no': '4.3',
#   'wind_speed': '1',
#   'wind_direc': '86',
#   'publishtime': '2023/07/22 11:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '4.7',
#   'pm10_avg': '15',
#   'so2_avg': '1',
#   'longitude': '121.64081',
# ...
